# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import plotly.express as px
import plotly.figure_factory as ff
from arch import arch_model

from ipywidgets import HBox, VBox, Dropdown, Output
from scipy.optimize import fmin, minimize
from scipy.stats import t
from scipy.stats import norm
from math import inf
from IPython.display import display

import bs4 as bs
import requests
import yfinance as yf
import datetime

# %%
def vecl(matrix):
    lower_matrix = np.tril(matrix,k=-1)
    array_with_zero = np.matrix(lower_matrix).A1

    array_without_zero = array_with_zero[array_with_zero!=0]

    return array_without_zero

# %%
def garch_t_to_u(rets, res):
    mu = res.params['mu']
    nu = res.params['nu']
    est_r = rets - mu
    h = res.conditional_volatility
    std_res = est_r / h
    # we could also just use:
    # std_res = res.std_resid
    # but it's useful to see what is going on
    udata = t.cdf(std_res, nu)
    return udata

# %%
def loglike_norm_dcc_copula(theta, udata):
    N, T = np.shape(udata)
    llf = np.zeros((T,1))
    trdata = np.array(norm.ppf(udata).T, ndmin=2)
    
    
    Rt, veclRt =  dcceq(theta,trdata)

    for i in range(0,T):
        llf[i] = -0.5* np.log(np.linalg.det(Rt[:,:,i]))
        llf[i] = llf[i] - 0.5 *  np.matmul(np.matmul(trdata[i,:] , (np.linalg.inv(Rt[:,:,i]) - np.eye(N))) ,trdata[i,:].T)
    llf = np.sum(llf)

    return -llf

# %%
def dcceq(theta,trdata):
    T, N = np.shape(trdata)

    a, b = theta
    
    if min(a,b)<0 or max(a,b)>1 or a+b > .999999:
        a = .9999 - b
        
    Qt = np.zeros((N, N ,T))

    Qt[:,:,0] = np.cov(trdata.T)

    Rt =  np.zeros((N, N ,T))
    veclRt =  np.zeros((T, int(N*(N-1)/2)))
    
    Rt[:,:,0] = np.corrcoef(trdata.T)
    
    for j in range(1,T):
        Qt[:,:,j] = Qt[:,:,0] * (1-a-b)
        Qt[:,:,j] = Qt[:,:,j] + a * np.matmul(trdata[[j-1]].T, trdata[[j-1]])
        Qt[:,:,j] = Qt[:,:,j] + b * Qt[:,:,j-1]
        Rt[:,:,j] = np.divide(Qt[:,:,j] , np.matmul(np.sqrt(np.array(np.diag(Qt[:,:,j]), ndmin=2)).T , np.sqrt(np.array(np.diag(Qt[:,:,j]), ndmin=2))))
    
    for j in range(0,T):
        veclRt[j, :] = vecl(Rt[:,:,j].T)
    return Rt, veclRt

# %%
def run_garch_on_return(rets, udata_list, model_parameters):
    for x in rets:
        am = arch_model(rets[x], dist = 't')
        short_name = x.split()[0]
        model_parameters[short_name] = am.fit(disp='off')
        udata = garch_t_to_u(rets[x], model_parameters[short_name])
        udata_list.append(udata)
    return udata_list, model_parameters

# %%
def update_corr_data(change):
    a1corr = rets.loc[:, pair_dropdown.value.split('-')].corr().values[0][1]
    a1dcc = pd.DataFrame(veclRt[:,corr_name_list.index(pair_dropdown.value)],index = rets.iloc[:,:5].dropna().index)
    a1dcc.columns = ['DCC']
    a1dcc['corr'] = a1corr
    corr_line_plot = px.line(a1dcc, title = 'DCC vs unconditional correlation for ' + pair_dropdown.value, width=1000, height=500)
    output_graphics.clear_output()
    with output_graphics:
        display(corr_line_plot)

# %%
rets = pd.read_csv('Compiled_Data.csv').set_index('Date')
Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#
# C:\Users\sadas\Anaconda3\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning:
#
# y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.146e-07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#
# C:\Users\sadas\Anaconda3\lib\site-packages\arch\univariate\base.py:755: ConvergenceWarning:
#
# The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#
# C:\Users\sadas\Anaconda3\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning:
#
# y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.842e-07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#
# C:\Users\sadas\Anaconda3\lib\site-packages\arch\univariate\base.py:755: ConvergenceWarning:
#
# The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
# {'USTC':                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                         USTC   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:                186.655
# Distribution:      Standardized Student's t   AIC:                          -363.310
# Method:                  Maximum Likelihood   BIC:                          -344.469
#                                               No. Observations:                  320
# Date:                      Fri, Dec 16 2022   Df Residuals:                      319
# Time:                              13:18:09   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0324  4.108e-04     78.834      0.000 [3.158e-02,3.319e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      1.2992e-06  1.233e-07     10.534  5.990e-26 [1.057e-06,1.541e-06]
# alpha[1]       0.6990      0.151      4.632  3.617e-06     [  0.403,  0.995]
# beta[1]        0.3010      0.144      2.083  3.726e-02   [1.777e-02,  0.584]
#                                  Distribution
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# nu           499.9066    532.381      0.939      0.348 [-5.435e+02,1.543e+03]
# =============================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x2d1f8547eb8, 'FRAX':                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                         FRAX   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:                1302.88
# Distribution:      Standardized Student's t   AIC:                          -2595.76
# Method:                  Maximum Likelihood   BIC:                          -2576.91
#                                               No. Observations:                  320
# Date:                      Fri, Dec 16 2022   Df Residuals:                      319
# Time:                              13:18:09   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.9964  2.466e-04   4041.190      0.000 [  0.996,  0.997]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      2.2913e-06  1.701e-09   1347.130      0.000 [2.288e-06,2.295e-06]
# alpha[1]       0.0919  2.372e-02      3.874  1.072e-04   [4.540e-02,  0.138]
# beta[1]        0.8880  9.827e-03     90.369      0.000     [  0.869,  0.907]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu            11.8874      0.205     58.086      0.000 [ 11.486, 12.288]
# ========================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x2d1f8526f98, 'AMPL':                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                         AMPL   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:                217.327
# Distribution:      Standardized Student's t   AIC:                          -424.654
# Method:                  Maximum Likelihood   BIC:                          -405.812
#                                               No. Observations:                  320
# Date:                      Fri, Dec 16 2022   Df Residuals:                      319
# Time:                              13:18:09   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.9571  3.604e-02     26.560 1.995e-155 [  0.887,  1.028]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      2.7393e-03  3.304e-03      0.829      0.407 [-3.736e-03,9.214e-03]
# alpha[1]       1.0000      0.135      7.412  1.243e-13      [  0.736,  1.264]
# beta[1]        0.0000      0.248      0.000      1.000      [ -0.487,  0.487]
#                                Distribution
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# nu            26.7842     54.777      0.489      0.625 [-80.577,1.341e+02]
# ==========================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x2d1f855a710, 'DAI':                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                          DAI   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:                1869.22
# Distribution:      Standardized Student's t   AIC:                          -3728.43
# Method:                  Maximum Likelihood   BIC:                          -3709.59
#                                               No. Observations:                  320
# Date:                      Fri, Dec 16 2022   Df Residuals:                      319
# Time:                              13:18:09   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.0000  3.835e-05  2.607e+04      0.000 [  1.000,  1.000]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      3.8466e-08  3.793e-08      1.014      0.311 [-3.588e-08,1.128e-07]
# alpha[1]       0.2000      0.364      0.549      0.583      [ -0.514,  0.914]
# beta[1]        0.7800      0.146      5.327  1.001e-07      [  0.493,  1.067]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             4.4242      1.628      2.718  6.572e-03 [  1.234,  7.615]
# ========================================================================
#
# Covariance estimator: robust
# WARNING: The optimizer did not indicate successful convergence. The message was Inequality constraints incompatible.
# See convergence_flag.
#
# ARCHModelResult, id: 0x2d1f857ec50, 'EOSDT':                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                        EOSDT   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:                310.008
# Distribution:      Standardized Student's t   AIC:                          -610.015
# Method:                  Maximum Likelihood   BIC:                          -591.173
#                                               No. Observations:                  320
# Date:                      Fri, Dec 16 2022   Df Residuals:                      319
# Time:                              13:18:09   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.9271  8.856e-03    104.684      0.000 [  0.910,  0.944]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      8.6836e-04  4.122e-04      2.107  3.514e-02 [6.048e-05,1.676e-03]
# alpha[1]       0.5351      0.106      5.037  4.739e-07     [  0.327,  0.743]
# beta[1]        0.4649  9.563e-02      4.861  1.168e-06     [  0.277,  0.652]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             9.7347      4.681      2.079  3.758e-02 [  0.559, 18.910]
# ========================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x2d1f85556d8, 'USDC':                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                         USDC   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:                2161.80
# Distribution:      Standardized Student's t   AIC:                          -4313.60
# Method:                  Maximum Likelihood   BIC:                          -4294.75
#                                               No. Observations:                  320
# Date:                      Fri, Dec 16 2022   Df Residuals:                      319
# Time:                              13:18:09   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.0000  2.335e-05  4.283e+04      0.000 [  1.000,  1.000]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      2.2922e-09  1.613e-08      0.142      0.887 [-2.932e-08,3.390e-08]
# alpha[1]       0.1000  4.110e-02      2.433  1.497e-02    [1.945e-02,  0.181]
# beta[1]        0.8800  3.270e-02     26.912 1.603e-159      [  0.816,  0.944]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             6.5569     17.133      0.383      0.702 [-27.024, 40.138]
# ========================================================================
#
# Covariance estimator: robust
# WARNING: The optimizer did not indicate successful convergence. The message was Inequality constraints incompatible.
# See convergence_flag.
#
# ARCHModelResult, id: 0x2d1f860f438, 'USDT':                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                         USDT   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:                2004.75
# Distribution:      Standardized Student's t   AIC:                          -3999.50
# Method:                  Maximum Likelihood   BIC:                          -3980.65
#                                               No. Observations:                  320
# Date:                      Fri, Dec 16 2022   Df Residuals:                      319
# Time:                              13:18:09   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.0000  5.205e-05  1.921e+04      0.000 [  1.000,  1.000]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      3.8416e-08  5.557e-08      0.691      0.489 [-7.050e-08,1.473e-07]
# alpha[1]       0.2000  2.150e-02      9.303  1.367e-20      [  0.158,  0.242]
# beta[1]        0.7000  8.594e-02      8.145  3.778e-16      [  0.532,  0.868]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             4.1315      1.886      2.190  2.850e-02 [  0.435,  7.829]
# ========================================================================
#
# Covariance estimator: robust
# WARNING: The optimizer did not indicate successful convergence. The message was Inequality constraints incompatible.
# See convergence_flag.
#
# ARCHModelResult, id: 0x2d1f860ff28, 'PAXG':                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                         PAXG   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:               -1704.78
# Distribution:      Standardized Student's t   AIC:                           3419.56
# Method:                  Maximum Likelihood   BIC:                           3438.40
#                                               No. Observations:                  320
# Date:                      Fri, Dec 16 2022   Df Residuals:                      319
# Time:                              13:18:09   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu          1824.3263      3.826    476.779      0.000 [1.817e+03,1.832e+03]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega        127.9642     75.266      1.700  8.910e-02 [-19.554,2.755e+02]
# alpha[1]       1.0000      0.140      7.119  1.090e-12   [  0.725,  1.275]
# beta[1]    1.5448e-15      0.152  1.018e-14      1.000   [ -0.297,  0.297]
#                                 Distribution
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# nu           235.3686     26.622      8.841  9.482e-19 [1.832e+02,2.875e+02]
# ============================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x2d1f8619668, 'XAUT':                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                         XAUT   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:               -1694.03
# Distribution:      Standardized Student's t   AIC:                           3398.07
# Method:                  Maximum Likelihood   BIC:                           3416.91
#                                               No. Observations:                  320
# Date:                      Fri, Dec 16 2022   Df Residuals:                      319
# Time:                              13:18:09   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu          1822.7769      5.917    308.058      0.000 [1.811e+03,1.834e+03]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega        108.8693     62.929      1.730  8.363e-02 [-14.470,2.322e+02]
# alpha[1]       0.9219      0.100      9.201  3.552e-20   [  0.726,  1.118]
# beta[1]        0.0735      0.123      0.600      0.549   [ -0.167,  0.314]
#                                 Distribution
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# nu           399.7658     10.263     38.952      0.000 [3.797e+02,4.199e+02]
# ============================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x2d1f860f5c0}

# %%
cons = ({'type': 'ineq', 'fun': lambda x:  -x[0]  -x[1] +1})
bnds = ((0, 0.5), (0, 0.9997))

# %time opt_out = minimize(loglike_norm_dcc_copula, [0.01, 0.95], args = (udata_list), bounds=bnds, constraints=cons)
# Out:
# Wall time: 5.49 s

# %%
print(opt_out.success)
print(opt_out.x)
# Out:
# True
# [0.23623014 0.69291251]

# %%
llf  = loglike_norm_dcc_copula(opt_out.x, udata_list)
llf
# Out:
# -1176.3110557632046

# %%
trdata = np.array(norm.ppf(udata_list).T, ndmin=2)
Rt, veclRt = dcceq(opt_out.x, trdata)

stock_names = [x.split()[0] for x in rets.columns]
corr_name_list = []
for i, name_a in enumerate(stock_names):
    if i == 0:
        pass
    else:
        for name_b in stock_names[:i]:
            corr_name_list.append(name_a + "-" + name_b)

# %%
garch_vol_df = pd.concat([pd.DataFrame(model_parameters[x].conditional_volatility/100)*1600 for x in model_parameters], axis=1)
garch_vol_df.columns = stock_names

# %%
stock1,stock2 = ["USTC","USDT"]
px.scatter(garch_vol_df, x = stock1, y=stock2, width=1000, height=500, title='GARCH Volatility').show()
# Out:
# <div>                            <div id="71336245-e2de-445e-8830-e46758f9f0f0" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("